# %%
import pandas as pd
c={1:'Country', 3:'Energy Supply', 4:'Energy Supply per Capita', 5:'% Renewable'}
fl=pd.read_excel("Energy Indicators.xls",header=None,footer=None)
d=pd.DataFrame(fl)
d.drop([0,2],axis=1,inplace=True)
d.drop(d.index[245:],inplace=True)
d.drop(d.index[:18],inplace=True)
d.rename(columns=c,inplace=True)
d.reset_index(inplace=True)
d.drop('index',axis=1,inplace=True)
f2=pd.read_csv('World.csv',header=None)
d2=pd.DataFrame(f2)
d2.drop(d2.index[:4],inplace=True)
d2.reset_index(inplace=True)
d2.drop('index',axis=1,inplace=True)
d2.columns=d2.iloc[0]
d2.drop(d2.index[0],inplace=True)
s1=pd.merge(d,d2,how='inner',on=['Country'])
#s1
#d2
d
# Out:
#                                                Country Energy Supply  \
# 0                                          Afghanistan           321
# 1                                              Albania           102
# 2                                              Algeria          1959
# 3                                       American Samoa           ...
# 4                                              Andorra             9
# 5                                               Angola           642
# 6                                             Anguilla             2
# 7                                  Antigua and Barbuda             8
# 8                                            Argentina          3378
# 9                                              Armenia           143
# 10                                               Aruba            12
# 11                                           Australia          5386
# 12                                             Austria          1391
# ...
